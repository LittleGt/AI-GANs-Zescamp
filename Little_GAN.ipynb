# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#ใช้แสดงเฉยๆ ว่าใช้ GPU คอม หรือ Colab
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense 
from tensorflow.keras.layers import Flatten, BatchNormalization
from tensorflow.keras.layers import Activation, ZeroPadding2D
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.layers import UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.optimizers import Adam
import numpy as np
from PIL import Image
from tqdm import tqdm
import os 
import time
import matplotlib.pyplot as plt

# %%
#สร้าง hms_string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60.
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
GENERATE_RES = 3 # Generation resolution factor 
# (1=32, 2=64, 3=96, 4=128, etc.)
GENERATE_SQUARE = 32 * GENERATE_RES # rows/cols (should be square)
IMAGE_CHANNELS = 3

# Preview image 
PREVIEW_ROWS = 1 #4
PREVIEW_COLS = 1 #7
PREVIEW_MARGIN = 1 #16

# Size vector to generate images from
SEED_SIZE = 100

# Configuration
DATA_PATH = '/content/drive/MyDrive/Dataset2'
EPOCHS = 4000
BATCH_SIZE = 32
BUFFER_SIZE = 60000

print(f"Will generate {GENERATE_SQUARE}px square images.")
# Out:
# Will generate 96px square images.

# %%
#output('Will generate 96px square images.')

# %%
training_binary_path = os.path.join(DATA_PATH,
        f'training_data_{GENERATE_SQUARE}_{GENERATE_SQUARE}.npy')

print(f"Looking for file: {training_binary_path}")

if not os.path.isfile(training_binary_path):
  start = time.time()
  print("Loading training images...")

  training_data = []
  faces_path = os.path.join(DATA_PATH)
  for filename in tqdm(os.listdir(faces_path)):
      path = os.path.join(faces_path,filename)
      image = Image.open(path).resize((GENERATE_SQUARE,
            GENERATE_SQUARE),Image.ANTIALIAS)
      training_data.append(np.asarray(image))
  training_data = np.reshape(training_data,(-1,GENERATE_SQUARE,
            GENERATE_SQUARE,IMAGE_CHANNELS))
  training_data = training_data.astype(np.float32)
  training_data = training_data / 127.5 - 1.


  print("Saving training image binary...")
  np.save(training_binary_path,training_data)
  elapsed = time.time()-start
  print (f'Image preprocess time: {hms_string(elapsed)}')
else:
  print("Loading previous training pickle...")
  training_data = np.load(training_binary_path)
# Out:
#   1%|▏         | 48/3698 [00:00<00:07, 477.24it/s]
# Looking for file: /content/drive/MyDrive/Dataset2/training_data_96_96.npy
# Loading training images...
# 100%|██████████| 3698/3698 [17:21<00:00,  3.55it/s]
# Saving training image binary...
# Image preprocess time: 0:17:22.74

# %%
train_dataset = tf.data.Dataset.from_tensor_slices(training_data).shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def build_generator(seed_size, channels):
    model = Sequential()

    model.add(Dense(4*4*256,activation="relu",input_dim=seed_size))
    model.add(Reshape((4,4,256)))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    model.add(UpSampling2D())
    model.add(Conv2D(256,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))
   
    # Output resolution, additional upsampling
    model.add(UpSampling2D())
    model.add(Conv2D(128,kernel_size=3,padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(Activation("relu"))

    if GENERATE_RES>1:
      model.add(UpSampling2D(size=(GENERATE_RES,GENERATE_RES)))
      model.add(Conv2D(128,kernel_size=3,padding="same"))
      model.add(BatchNormalization(momentum=0.8))
      model.add(Activation("relu"))

    # Final CNN layer
    model.add(Conv2D(channels,kernel_size=3,padding="same"))
    model.add(Activation("tanh"))

    return model


def build_discriminator(image_shape):
    model = Sequential()

    model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=image_shape, 
                     padding="same"))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
    model.add(ZeroPadding2D(padding=((0,1),(0,1))))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(256, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Conv2D(512, kernel_size=3, strides=1, padding="same"))
    model.add(BatchNormalization(momentum=0.8))
    model.add(LeakyReLU(alpha=0.2))

    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(1, activation='sigmoid'))

    return model

# %%
def save_images(cnt,noise):
  image_array = np.full(( 
      PREVIEW_MARGIN + (PREVIEW_ROWS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 
      PREVIEW_MARGIN + (PREVIEW_COLS * (GENERATE_SQUARE+PREVIEW_MARGIN)), 3), 
      255, dtype=np.uint8)
  
  generated_images = generator.predict(noise)

  generated_images = 0.5 * generated_images + 0.5

  image_count = 0
  for row in range(PREVIEW_ROWS):
      for col in range(PREVIEW_COLS):
        r = row * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        c = col * (GENERATE_SQUARE+16) + PREVIEW_MARGIN
        image_array[r:r+GENERATE_SQUARE,c:c+GENERATE_SQUARE] = generated_images[image_count] * 255
        image_count += 1

          
  output_path = os.path.join(DATA_PATH,'output')
  if not os.path.exists(output_path):
    os.makedirs(output_path)
  
  filename = os.path.join(output_path,f"train-{cnt}.png")
  im = Image.fromarray(image_array)
  im.save(filename)

# %%
generator = build_generator(SEED_SIZE, IMAGE_CHANNELS)

noise = tf.random.normal([1, SEED_SIZE])
generated_image = generator(noise, training=False)

plt.imshow(generated_image[0, :, :, 0])

# %%
image_shape = (GENERATE_SQUARE,GENERATE_SQUARE,IMAGE_CHANNELS)

discriminator = build_discriminator(image_shape)
decision = discriminator(generated_image)
print (decision)
# Out:
# tf.Tensor([[0.49975216]], shape=(1, 1), dtype=float32)

# %%
cross_entropy = tf.keras.losses.BinaryCrossentropy()

def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss

def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)

# %%
generator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(1.5e-4,0.5)

# %%
@tf.function
def train_step(images):
  seed = tf.random.normal([BATCH_SIZE, SEED_SIZE])

  with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
    generated_images = generator(seed, training=True)

    real_output = discriminator(images, training=True)
    fake_output = discriminator(generated_images, training=True)

    gen_loss = generator_loss(fake_output)
    disc_loss = discriminator_loss(real_output, fake_output)
    

    gradients_of_generator = gen_tape.gradient(\
        gen_loss, generator.trainable_variables)
    gradients_of_discriminator = disc_tape.gradient(\
        disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(
        gradients_of_generator, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(
        gradients_of_discriminator, 
        discriminator.trainable_variables))
  return gen_loss,disc_loss

# %%
def train(dataset, epochs):
  fixed_seed = np.random.normal(0, 1, (PREVIEW_ROWS * PREVIEW_COLS, 
                                       SEED_SIZE))
  start = time.time()

  for epoch in range(epochs):
    epoch_start = time.time()

    gen_loss_list = []
    disc_loss_list = []

    for image_batch in dataset:
      t = train_step(image_batch)
      gen_loss_list.append(t[0])
      disc_loss_list.append(t[1])

    g_loss = sum(gen_loss_list) / len(gen_loss_list)
    d_loss = sum(disc_loss_list) / len(disc_loss_list)

    epoch_elapsed = time.time()-epoch_start
    print (f'Epoch {epoch+1}, gen loss={g_loss},disc loss={d_loss},'\
           ' {hms_string(epoch_elapsed)}')
    save_images(epoch,fixed_seed)

  elapsed = time.time()-start
  print (f'Training time: {hms_string(elapsed)}')

# %%
train(train_dataset, EPOCHS)
# Out:
# Epoch 1, gen loss=2.647261619567871,disc loss=0.9985617399215698, {hms_string(epoch_elapsed)}
# Epoch 2, gen loss=4.557541370391846,disc loss=0.863332211971283, {hms_string(epoch_elapsed)}
# Epoch 3, gen loss=2.2409160137176514,disc loss=1.6019607782363892, {hms_string(epoch_elapsed)}
# Epoch 4, gen loss=1.9067145586013794,disc loss=1.2946364879608154, {hms_string(epoch_elapsed)}
# Epoch 5, gen loss=1.9935753345489502,disc loss=1.213993787765503, {hms_string(epoch_elapsed)}
# Epoch 6, gen loss=2.4714441299438477,disc loss=1.1058707237243652, {hms_string(epoch_elapsed)}
# Epoch 7, gen loss=2.7881810665130615,disc loss=0.9424450397491455, {hms_string(epoch_elapsed)}
# Epoch 8, gen loss=2.665771484375,disc loss=1.1072272062301636, {hms_string(epoch_elapsed)}
# Epoch 9, gen loss=2.664741039276123,disc loss=0.9792707562446594, {hms_string(epoch_elapsed)}
# Epoch 10, gen loss=1.9754222631454468,disc loss=1.3373808860778809, {hms_string(epoch_elapsed)}
# Epoch 11, gen loss=1.9849026203155518,disc loss=1.0894172191619873, {hms_string(epoch_elapsed)}
# Epoch 12, gen loss=1.917263388633728,disc loss=1.2632896900177002, {hms_string(epoch_elapsed)}
# Epoch 13, gen loss=1.7996643781661987,disc loss=1.32685387134552, {hms_string(epoch_elapsed)}
# Epoch 14, gen loss=1.9845921993255615,disc loss=1.1870346069335938, {hms_string(epoch_elapsed)}
# Epoch 15, gen loss=1.7252506017684937,disc loss=1.286718726158142, {hms_string(epoch_elapsed)}
# Epoch 16, gen loss=1.8293850421905518,disc loss=1.2870795726776123, {hms_string(epoch_elapsed)}
# Epoch 17, gen loss=1.7862144708633423,disc loss=1.2017139196395874, {hms_string(epoch_elapsed)}
# Epoch 18, gen loss=2.0162041187286377,disc loss=1.1152247190475464, {hms_string(epoch_elapsed)}
# Epoch 19, gen loss=1.8522080183029175,disc loss=1.1793700456619263, {hms_string(epoch_elapsed)}
# Epoch 20, gen loss=2.0703155994415283,disc loss=1.1858528852462769, {hms_string(epoch_elapsed)}
# Epoch 21, gen loss=1.8767718076705933,disc loss=1.1586408615112305, {hms_string(epoch_elapsed)}
# Epoch 22, gen loss=1.901881217956543,disc loss=1.2082934379577637, {hms_string(epoch_elapsed)}
# Epoch 23, gen loss=1.8767547607421875,disc loss=1.225277066230774, {hms_string(epoch_elapsed)}
# Epoch 24, gen loss=1.908303141593933,disc loss=1.1977883577346802, {hms_string(epoch_elapsed)}
# Epoch 25, gen loss=1.872819185256958,disc loss=1.1581575870513916, {hms_string(epoch_elapsed)}
# Epoch 26, gen loss=1.8748886585235596,disc loss=1.1567511558532715, {hms_string(epoch_elapsed)}
# Epoch 27, gen loss=1.9077614545822144,disc loss=1.085185170173645, {hms_string(epoch_elapsed)}
# Epoch 28, gen loss=1.9972373247146606,disc loss=1.1978338956832886, {hms_string(epoch_elapsed)}
# Epoch 29, gen loss=1.828758716583252,disc loss=1.1174356937408447, {hms_string(epoch_elapsed)}
# Epoch 30, gen loss=2.106926918029785,disc loss=1.1069612503051758, {hms_string(epoch_elapsed)}
# Epoch 31, gen loss=2.1432764530181885,disc loss=1.072746992111206, {hms_string(epoch_elapsed)}
# Epoch 32, gen loss=1.9598387479782104,disc loss=1.1278891563415527, {hms_string(epoch_elapsed)}
# Epoch 33, gen loss=1.982513189315796,disc loss=1.122373104095459, {hms_string(epoch_elapsed)}
# Epoch 34, gen loss=2.132873296737671,disc loss=0.9874752163887024, {hms_string(epoch_elapsed)}
# Epoch 35, gen loss=2.1632704734802246,disc loss=1.1294941902160645, {hms_string(epoch_elapsed)}
# Epoch 36, gen loss=2.011338710784912,disc loss=1.0947378873825073, {hms_string(epoch_elapsed)}
# Epoch 37, gen loss=2.096839427947998,disc loss=1.1031922101974487, {hms_string(epoch_elapsed)}
# Epoch 38, gen loss=2.0769050121307373,disc loss=1.03237783908844, {hms_string(epoch_elapsed)}
# Epoch 39, gen loss=2.0410494804382324,disc loss=1.0734587907791138, {hms_string(epoch_elapsed)}
# Epoch 40, gen loss=2.1862599849700928,disc loss=1.0276439189910889, {hms_string(epoch_elapsed)}
# Epoch 41, gen loss=2.0865120887756348,disc loss=1.0356507301330566, {hms_string(epoch_elapsed)}
# Epoch 42, gen loss=2.0153493881225586,disc loss=1.0168529748916626, {hms_string(epoch_elapsed)}
# Epoch 43, gen loss=2.142991065979004,disc loss=0.9774603843688965, {hms_string(epoch_elapsed)}
# Epoch 44, gen loss=2.0962727069854736,disc loss=1.02568519115448, {hms_string(epoch_elapsed)}
# Epoch 45, gen loss=2.2007088661193848,disc loss=0.997382640838623, {hms_string(epoch_elapsed)}
# Epoch 46, gen loss=2.229341506958008,disc loss=1.0068037509918213, {hms_string(epoch_elapsed)}
# Epoch 47, gen loss=2.3271965980529785,disc loss=0.9004411101341248, {hms_string(epoch_elapsed)}
# Epoch 48, gen loss=2.2357382774353027,disc loss=0.9314783811569214, {hms_string(epoch_elapsed)}
# Epoch 49, gen loss=2.3293046951293945,disc loss=0.9855476021766663, {hms_string(epoch_elapsed)}
# Epoch 50, gen loss=2.2406837940216064,disc loss=0.9875144958496094, {hms_string(epoch_elapsed)}
# Epoch 51, gen loss=2.2780003547668457,disc loss=1.0326780080795288, {hms_string(epoch_elapsed)}
# Epoch 52, gen loss=2.2333836555480957,disc loss=0.9622512459754944, {hms_string(epoch_elapsed)}
# Epoch 53, gen loss=2.347625732421875,disc loss=0.9125097393989563, {hms_string(epoch_elapsed)}
# Epoch 54, gen loss=2.2246150970458984,disc loss=0.9810552000999451, {hms_string(epoch_elapsed)}
# Epoch 55, gen loss=2.2209763526916504,disc loss=0.963996171951294, {hms_string(epoch_elapsed)}
# Epoch 56, gen loss=2.2976179122924805,disc loss=0.9156540036201477, {hms_string(epoch_elapsed)}
# Epoch 57, gen loss=2.2856431007385254,disc loss=0.9536663293838501, {hms_string(epoch_elapsed)}
# Epoch 58, gen loss=2.211319923400879,disc loss=0.9304029941558838, {hms_string(epoch_elapsed)}
# Epoch 59, gen loss=2.254455804824829,disc loss=0.9519591331481934, {hms_string(epoch_elapsed)}
# Epoch 60, gen loss=2.21117901802063,disc loss=0.9610153436660767, {hms_string(epoch_elapsed)}
# Epoch 61, gen loss=2.2085494995117188,disc loss=0.8847188353538513, {hms_string(epoch_elapsed)}
# Epoch 62, gen loss=2.366447925567627,disc loss=0.9910873174667358, {hms_string(epoch_elapsed)}
# Epoch 63, gen loss=2.410304546356201,disc loss=0.8707095980644226, {hms_string(epoch_elapsed)}
# Epoch 64, gen loss=2.2667222023010254,disc loss=0.8949722051620483, {hms_string(epoch_elapsed)}
# Epoch 65, gen loss=2.455923557281494,disc loss=0.8405819535255432, {hms_string(epoch_elapsed)}
# Epoch 66, gen loss=2.2750680446624756,disc loss=0.8602403402328491, {hms_string(epoch_elapsed)}
# Epoch 67, gen loss=2.4343760013580322,disc loss=0.8299230337142944, {hms_string(epoch_elapsed)}
# Epoch 68, gen loss=2.4064478874206543,disc loss=0.8912473917007446, {hms_string(epoch_elapsed)}
# Epoch 69, gen loss=2.411404848098755,disc loss=0.8557484745979309, {hms_string(epoch_elapsed)}
# Epoch 70, gen loss=2.49330735206604,disc loss=0.8488000631332397, {hms_string(epoch_elapsed)}
# Epoch 71, gen loss=2.3835489749908447,disc loss=0.926148533821106, {hms_string(epoch_elapsed)}
# Epoch 72, gen loss=2.4108545780181885,disc loss=0.8320850729942322, {hms_string(epoch_elapsed)}
# Epoch 73, gen loss=2.5713255405426025,disc loss=0.8841751217842102, {hms_string(epoch_elapsed)}
# Epoch 74, gen loss=2.4845964908599854,disc loss=0.9134533405303955, {hms_string(epoch_elapsed)}
# Epoch 75, gen loss=2.386288642883301,disc loss=0.8698000907897949, {hms_string(epoch_elapsed)}
# Epoch 76, gen loss=2.6293349266052246,disc loss=0.8487481474876404, {hms_string(epoch_elapsed)}
# Epoch 77, gen loss=2.555471420288086,disc loss=0.8148465752601624, {hms_string(epoch_elapsed)}
# Epoch 78, gen loss=2.505781650543213,disc loss=0.8579850792884827, {hms_string(epoch_elapsed)}
# Epoch 79, gen loss=2.504573106765747,disc loss=0.8505604267120361, {hms_string(epoch_elapsed)}
# Epoch 80, gen loss=2.5846149921417236,disc loss=0.7834383845329285, {hms_string(epoch_elapsed)}
# Epoch 81, gen loss=2.516162157058716,disc loss=0.7665693163871765, {hms_string(epoch_elapsed)}
# Epoch 82, gen loss=2.6329503059387207,disc loss=0.8423414826393127, {hms_string(epoch_elapsed)}
# Epoch 83, gen loss=2.6416189670562744,disc loss=0.8404616117477417, {hms_string(epoch_elapsed)}
# Epoch 84, gen loss=2.617222309112549,disc loss=0.7849066257476807, {hms_string(epoch_elapsed)}
# Epoch 85, gen loss=2.603184700012207,disc loss=0.8753973245620728, {hms_string(epoch_elapsed)}
# Epoch 86, gen loss=2.700227975845337,disc loss=0.8171581029891968, {hms_string(epoch_elapsed)}
# Epoch 87, gen loss=2.6131720542907715,disc loss=0.8105860948562622, {hms_string(epoch_elapsed)}
# Epoch 88, gen loss=2.5998635292053223,disc loss=0.7644736170768738, {hms_string(epoch_elapsed)}
# Epoch 89, gen loss=2.639253854751587,disc loss=0.8379166126251221, {hms_string(epoch_elapsed)}
# Epoch 90, gen loss=2.6477041244506836,disc loss=0.8351735472679138, {hms_string(epoch_elapsed)}
# Epoch 91, gen loss=2.6078929901123047,disc loss=0.8899404406547546, {hms_string(epoch_elapsed)}
# Epoch 92, gen loss=2.5808217525482178,disc loss=0.7964890599250793, {hms_string(epoch_elapsed)}
# Epoch 93, gen loss=2.5121328830718994,disc loss=0.8245447278022766, {hms_string(epoch_elapsed)}
# Epoch 94, gen loss=2.606863260269165,disc loss=0.8217087388038635, {hms_string(epoch_elapsed)}
# Epoch 95, gen loss=2.7146952152252197,disc loss=0.7248114943504333, {hms_string(epoch_elapsed)}
# Epoch 96, gen loss=2.735356569290161,disc loss=0.7368286848068237, {hms_string(epoch_elapsed)}
# Epoch 97, gen loss=2.813107490539551,disc loss=0.7971190810203552, {hms_string(epoch_elapsed)}
# Epoch 98, gen loss=2.8287603855133057,disc loss=0.8079996705055237, {hms_string(epoch_elapsed)}
# Epoch 99, gen loss=2.7894434928894043,disc loss=0.7898661494255066, {hms_string(epoch_elapsed)}
# Epoch 100, gen loss=2.8245108127593994,disc loss=0.746120035648346, {hms_string(epoch_elapsed)}
# Epoch 101, gen loss=2.6928670406341553,disc loss=0.744698703289032, {hms_string(epoch_elapsed)}
# Epoch 102, gen loss=2.7804839611053467,disc loss=0.7622324824333191, {hms_string(epoch_elapsed)}
# Epoch 103, gen loss=2.7672460079193115,disc loss=0.7654052972793579, {hms_string(epoch_elapsed)}
# Epoch 104, gen loss=2.9375410079956055,disc loss=0.7062434554100037, {hms_string(epoch_elapsed)}
# Epoch 105, gen loss=2.871163845062256,disc loss=0.753240168094635, {hms_string(epoch_elapsed)}
# Epoch 106, gen loss=2.921675205230713,disc loss=0.7286940217018127, {hms_string(epoch_elapsed)}
# Epoch 107, gen loss=2.8351526260375977,disc loss=0.6638416051864624, {hms_string(epoch_elapsed)}
# Epoch 108, gen loss=2.8806612491607666,disc loss=0.7009486556053162, {hms_string(epoch_elapsed)}
# Epoch 109, gen loss=3.0056629180908203,disc loss=0.7497910261154175, {hms_string(epoch_elapsed)}
# Epoch 110, gen loss=2.8774218559265137,disc loss=0.727051317691803, {hms_string(epoch_elapsed)}
# Epoch 111, gen loss=2.9481558799743652,disc loss=0.8296935558319092, {hms_string(epoch_elapsed)}
# Epoch 112, gen loss=2.9527246952056885,disc loss=0.6889817714691162, {hms_string(epoch_elapsed)}
# Epoch 113, gen loss=2.9083547592163086,disc loss=0.6933438777923584, {hms_string(epoch_elapsed)}
# Epoch 114, gen loss=2.9687047004699707,disc loss=0.688793957233429, {hms_string(epoch_elapsed)}
# Epoch 115, gen loss=2.9723873138427734,disc loss=0.7692469954490662, {hms_string(epoch_elapsed)}
# Epoch 116, gen loss=2.9634718894958496,disc loss=0.6754497289657593, {hms_string(epoch_elapsed)}
# Epoch 117, gen loss=2.946699380874634,disc loss=0.7227256298065186, {hms_string(epoch_elapsed)}
# Epoch 118, gen loss=3.0038812160491943,disc loss=0.6678417325019836, {hms_string(epoch_elapsed)}
# Epoch 119, gen loss=3.029029369354248,disc loss=0.6446347236633301, {hms_string(epoch_elapsed)}
# Epoch 120, gen loss=2.9853968620300293,disc loss=0.7193785309791565, {hms_string(epoch_elapsed)}
# Epoch 121, gen loss=3.1194381713867188,disc loss=0.6897382140159607, {hms_string(epoch_elapsed)}
# Epoch 122, gen loss=3.1263725757598877,disc loss=0.6475930213928223, {hms_string(epoch_elapsed)}
# Epoch 123, gen loss=3.191011905670166,disc loss=0.5858932733535767, {hms_string(epoch_elapsed)}
# Epoch 124, gen loss=3.1596431732177734,disc loss=0.6190140843391418, {hms_string(epoch_elapsed)}
# Epoch 125, gen loss=3.1044373512268066,disc loss=0.6530037522315979, {hms_string(epoch_elapsed)}
# Epoch 126, gen loss=3.159820556640625,disc loss=0.7356958985328674, {hms_string(epoch_elapsed)}
# Epoch 127, gen loss=3.230757713317871,disc loss=0.6997325420379639, {hms_string(epoch_elapsed)}
# Epoch 128, gen loss=3.267996072769165,disc loss=0.6507480144500732, {hms_string(epoch_elapsed)}
# Epoch 129, gen loss=3.2101480960845947,disc loss=0.6173934936523438, {hms_string(epoch_elapsed)}
# Epoch 130, gen loss=3.263637065887451,disc loss=0.6159943342208862, {hms_string(epoch_elapsed)}
# Epoch 131, gen loss=3.0947961807250977,disc loss=0.6408113241195679, {hms_string(epoch_elapsed)}
# Epoch 132, gen loss=3.1506221294403076,disc loss=0.6407638788223267, {hms_string(epoch_elapsed)}
# Epoch 133, gen loss=3.3352150917053223,disc loss=0.6342117786407471, {hms_string(epoch_elapsed)}
# Epoch 134, gen loss=3.358750820159912,disc loss=0.6274958252906799, {hms_string(epoch_elapsed)}
# Epoch 135, gen loss=3.3399200439453125,disc loss=0.6368874311447144, {hms_string(epoch_elapsed)}
# Epoch 136, gen loss=3.297245502471924,disc loss=0.681740403175354, {hms_string(epoch_elapsed)}
# Epoch 137, gen loss=3.3109018802642822,disc loss=0.6502826809883118, {hms_string(epoch_elapsed)}
# Epoch 138, gen loss=3.2908151149749756,disc loss=0.6012749671936035, {hms_string(epoch_elapsed)}
# Epoch 139, gen loss=3.2883753776550293,disc loss=0.6270749568939209, {hms_string(epoch_elapsed)}
# Epoch 140, gen loss=3.36014723777771,disc loss=0.6611946225166321, {hms_string(epoch_elapsed)}
# Epoch 141, gen loss=3.3887836933135986,disc loss=0.66493159532547, {hms_string(epoch_elapsed)}
# Epoch 142, gen loss=3.3480520248413086,disc loss=0.6058136224746704, {hms_string(epoch_elapsed)}
# Epoch 143, gen loss=3.3446767330169678,disc loss=0.623786985874176, {hms_string(epoch_elapsed)}
# Epoch 144, gen loss=3.379779577255249,disc loss=0.5902056097984314, {hms_string(epoch_elapsed)}
# Epoch 145, gen loss=3.36468768119812,disc loss=0.6276767253875732, {hms_string(epoch_elapsed)}
# Epoch 146, gen loss=3.3431448936462402,disc loss=0.6407883167266846, {hms_string(epoch_elapsed)}
# Epoch 147, gen loss=3.3239288330078125,disc loss=0.5860866904258728, {hms_string(epoch_elapsed)}
# Epoch 148, gen loss=3.4867966175079346,disc loss=0.6060956120491028, {hms_string(epoch_elapsed)}
# Epoch 149, gen loss=3.4512903690338135,disc loss=0.5409292578697205, {hms_string(epoch_elapsed)}
# Epoch 150, gen loss=3.5680813789367676,disc loss=0.6053815484046936, {hms_string(epoch_elapsed)}
# Epoch 151, gen loss=3.6236133575439453,disc loss=0.652991533279419, {hms_string(epoch_elapsed)}
# Epoch 152, gen loss=3.428466796875,disc loss=0.6387620568275452, {hms_string(epoch_elapsed)}
# Epoch 153, gen loss=3.5072343349456787,disc loss=0.5320829153060913, {hms_string(epoch_elapsed)}
# Epoch 154, gen loss=3.5438568592071533,disc loss=0.6467159986495972, {hms_string(epoch_elapsed)}
# Epoch 155, gen loss=3.507366418838501,disc loss=0.5965933203697205, {hms_string(epoch_elapsed)}
# Epoch 156, gen loss=3.573488712310791,disc loss=0.5995445251464844, {hms_string(epoch_elapsed)}
# Epoch 157, gen loss=3.648864984512329,disc loss=0.4934062659740448, {hms_string(epoch_elapsed)}
# Epoch 158, gen loss=3.686378002166748,disc loss=0.48993757367134094, {hms_string(epoch_elapsed)}
# Epoch 159, gen loss=3.716773748397827,disc loss=0.5922781825065613, {hms_string(epoch_elapsed)}
# Epoch 160, gen loss=3.728301525115967,disc loss=0.6228655576705933, {hms_string(epoch_elapsed)}
# Epoch 161, gen loss=3.637463092803955,disc loss=0.5669184923171997, {hms_string(epoch_elapsed)}
# Epoch 162, gen loss=3.7109479904174805,disc loss=0.5986502170562744, {hms_string(epoch_elapsed)}
# Epoch 163, gen loss=3.668128252029419,disc loss=0.6475011110305786, {hms_string(epoch_elapsed)}
# Epoch 164, gen loss=3.700791120529175,disc loss=0.539044201374054, {hms_string(epoch_elapsed)}
# Epoch 165, gen loss=3.747556209564209,disc loss=0.500155508518219, {hms_string(epoch_elapsed)}
# Epoch 166, gen loss=3.704450845718384,disc loss=0.5519986748695374, {hms_string(epoch_elapsed)}
# Epoch 167, gen loss=3.7627713680267334,disc loss=0.541408896446228, {hms_string(epoch_elapsed)}
# Epoch 168, gen loss=3.736750841140747,disc loss=0.5267506837844849, {hms_string(epoch_elapsed)}
# Epoch 169, gen loss=3.8108246326446533,disc loss=0.5168315768241882, {hms_string(epoch_elapsed)}
# Epoch 170, gen loss=3.7148354053497314,disc loss=0.4578300416469574, {hms_string(epoch_elapsed)}
# Epoch 171, gen loss=3.7877228260040283,disc loss=0.5233234167098999, {hms_string(epoch_elapsed)}
# Epoch 172, gen loss=3.891075849533081,disc loss=0.5633040070533752, {hms_string(epoch_elapsed)}
# Epoch 173, gen loss=3.9602792263031006,disc loss=0.5194259285926819, {hms_string(epoch_elapsed)}
# Epoch 174, gen loss=4.048863887786865,disc loss=0.5366716384887695, {hms_string(epoch_elapsed)}
# Epoch 175, gen loss=4.110279560089111,disc loss=0.5181307792663574, {hms_string(epoch_elapsed)}
# Epoch 176, gen loss=3.783475875854492,disc loss=0.5193794369697571, {hms_string(epoch_elapsed)}
# Epoch 177, gen loss=4.090186595916748,disc loss=0.43967384099960327, {hms_string(epoch_elapsed)}
# Epoch 178, gen loss=4.173559188842773,disc loss=0.5686017870903015, {hms_string(epoch_elapsed)}
# Epoch 179, gen loss=3.961822509765625,disc loss=0.5030867457389832, {hms_string(epoch_elapsed)}
# Epoch 180, gen loss=4.015480995178223,disc loss=0.44474154710769653, {hms_string(epoch_elapsed)}
# Epoch 181, gen loss=4.059686660766602,disc loss=0.49822694063186646, {hms_string(epoch_elapsed)}
# Epoch 182, gen loss=4.141145706176758,disc loss=0.5010315775871277, {hms_string(epoch_elapsed)}
# Epoch 183, gen loss=3.943147659301758,disc loss=0.48241275548934937, {hms_string(epoch_elapsed)}
# Epoch 184, gen loss=3.9398021697998047,disc loss=0.5662811398506165, {hms_string(epoch_elapsed)}
# Epoch 185, gen loss=4.002562522888184,disc loss=0.5209565758705139, {hms_string(epoch_elapsed)}
# Epoch 186, gen loss=3.9201111793518066,disc loss=0.4278610050678253, {hms_string(epoch_elapsed)}
# Epoch 187, gen loss=4.049010753631592,disc loss=0.4362631142139435, {hms_string(epoch_elapsed)}
# Epoch 188, gen loss=4.150134563446045,disc loss=0.4853530824184418, {hms_string(epoch_elapsed)}
# Epoch 189, gen loss=4.143023490905762,disc loss=0.5395509004592896, {hms_string(epoch_elapsed)}
# Epoch 190, gen loss=4.159843921661377,disc loss=0.4959554374217987, {hms_string(epoch_elapsed)}
# Epoch 191, gen loss=4.273089408874512,disc loss=0.5117453336715698, {hms_string(epoch_elapsed)}
# Epoch 192, gen loss=4.147270679473877,disc loss=0.39486661553382874, {hms_string(epoch_elapsed)}
# Epoch 193, gen loss=4.408015727996826,disc loss=0.4749101996421814, {hms_string(epoch_elapsed)}
# Epoch 194, gen loss=4.283445358276367,disc loss=0.4455554187297821, {hms_string(epoch_elapsed)}
# Epoch 195, gen loss=4.277623653411865,disc loss=0.40278762578964233, {hms_string(epoch_elapsed)}
# Epoch 196, gen loss=4.205406665802002,disc loss=0.47850674390792847, {hms_string(epoch_elapsed)}
# Epoch 197, gen loss=4.272395133972168,disc loss=0.48347008228302, {hms_string(epoch_elapsed)}
# Epoch 198, gen loss=4.208161354064941,disc loss=0.4493364989757538, {hms_string(epoch_elapsed)}
# Epoch 199, gen loss=4.181309223175049,disc loss=0.4232823848724365, {hms_string(epoch_elapsed)}
# Epoch 200, gen loss=4.35225248336792,disc loss=0.4615877866744995, {hms_string(epoch_elapsed)}
# Epoch 201, gen loss=4.253513336181641,disc loss=0.4355139136314392, {hms_string(epoch_elapsed)}
# Epoch 202, gen loss=4.313633441925049,disc loss=0.3976060748100281, {hms_string(epoch_elapsed)}
# Epoch 203, gen loss=4.323088645935059,disc loss=0.4883781969547272, {hms_string(epoch_elapsed)}
# Epoch 204, gen loss=4.5450029373168945,disc loss=0.5062400698661804, {hms_string(epoch_elapsed)}
# Epoch 205, gen loss=4.372225761413574,disc loss=0.47319546341896057, {hms_string(epoch_elapsed)}
# Epoch 206, gen loss=4.475143909454346,disc loss=0.4421515166759491, {hms_string(epoch_elapsed)}
# Epoch 207, gen loss=4.42412805557251,disc loss=0.40535542368888855, {hms_string(epoch_elapsed)}
# Epoch 208, gen loss=4.398550510406494,disc loss=0.4555805027484894, {hms_string(epoch_elapsed)}
# Epoch 209, gen loss=4.547368049621582,disc loss=0.41158512234687805, {hms_string(epoch_elapsed)}
# Epoch 210, gen loss=4.540435314178467,disc loss=0.4235071837902069, {hms_string(epoch_elapsed)}
# Epoch 211, gen loss=4.43173885345459,disc loss=0.47879549860954285, {hms_string(epoch_elapsed)}
# Epoch 212, gen loss=4.513795852661133,disc loss=0.4360107481479645, {hms_string(epoch_elapsed)}
# Epoch 213, gen loss=4.629032611846924,disc loss=0.41640594601631165, {hms_string(epoch_elapsed)}
# Epoch 214, gen loss=4.574280261993408,disc loss=0.39076220989227295, {hms_string(epoch_elapsed)}
# Epoch 215, gen loss=4.555027484893799,disc loss=0.497967928647995, {hms_string(epoch_elapsed)}
# Epoch 216, gen loss=4.556331634521484,disc loss=0.4030136466026306, {hms_string(epoch_elapsed)}
# Epoch 217, gen loss=4.656353950500488,disc loss=0.3904240131378174, {hms_string(epoch_elapsed)}
# Epoch 218, gen loss=4.560880661010742,disc loss=0.4802500307559967, {hms_string(epoch_elapsed)}
# Epoch 219, gen loss=4.617920875549316,disc loss=0.48909640312194824, {hms_string(epoch_elapsed)}
# Epoch 220, gen loss=4.578054428100586,disc loss=0.3945108950138092, {hms_string(epoch_elapsed)}
# Epoch 221, gen loss=4.573571681976318,disc loss=0.39777207374572754, {hms_string(epoch_elapsed)}
# Epoch 222, gen loss=4.514133930206299,disc loss=0.40084412693977356, {hms_string(epoch_elapsed)}
# Epoch 223, gen loss=4.688121318817139,disc loss=0.5151297450065613, {hms_string(epoch_elapsed)}
# Epoch 224, gen loss=4.64766788482666,disc loss=0.3669824004173279, {hms_string(epoch_elapsed)}
# Epoch 225, gen loss=4.591452121734619,disc loss=0.43914148211479187, {hms_string(epoch_elapsed)}
# Epoch 226, gen loss=4.764089584350586,disc loss=0.4659879207611084, {hms_string(epoch_elapsed)}
# Epoch 227, gen loss=4.560354709625244,disc loss=0.5512985587120056, {hms_string(epoch_elapsed)}
# Epoch 228, gen loss=4.731797218322754,disc loss=0.3589630424976349, {hms_string(epoch_elapsed)}
# Epoch 229, gen loss=4.755768775939941,disc loss=0.46414998173713684, {hms_string(epoch_elapsed)}
# Epoch 230, gen loss=4.703765392303467,disc loss=0.39503899216651917, {hms_string(epoch_elapsed)}
# Epoch 231, gen loss=4.710638999938965,disc loss=0.3767026364803314, {hms_string(epoch_elapsed)}
# Epoch 232, gen loss=4.8737945556640625,disc loss=0.32665321230888367, {hms_string(epoch_elapsed)}
# Epoch 233, gen loss=4.772232532501221,disc loss=0.3675583600997925, {hms_string(epoch_elapsed)}
# Epoch 234, gen loss=4.795568943023682,disc loss=0.37632468342781067, {hms_string(epoch_elapsed)}
# Epoch 235, gen loss=4.7811479568481445,disc loss=0.44496220350265503, {hms_string(epoch_elapsed)}
# Epoch 236, gen loss=4.718819618225098,disc loss=0.37741219997406006, {hms_string(epoch_elapsed)}
# Epoch 237, gen loss=4.798729419708252,disc loss=0.45632344484329224, {hms_string(epoch_elapsed)}
# Epoch 238, gen loss=4.862496852874756,disc loss=0.3679165244102478, {hms_string(epoch_elapsed)}
# Epoch 239, gen loss=4.634692668914795,disc loss=0.4129209518432617, {hms_string(epoch_elapsed)}
# Epoch 240, gen loss=4.83460807800293,disc loss=0.36070770025253296, {hms_string(epoch_elapsed)}
# Epoch 241, gen loss=4.900771617889404,disc loss=0.3483883738517761, {hms_string(epoch_elapsed)}
# Epoch 242, gen loss=4.838154315948486,disc loss=0.3724096417427063, {hms_string(epoch_elapsed)}
# Epoch 243, gen loss=4.809877395629883,disc loss=0.46202537417411804, {hms_string(epoch_elapsed)}
# Epoch 244, gen loss=4.632200241088867,disc loss=0.431533545255661, {hms_string(epoch_elapsed)}
# Epoch 245, gen loss=4.937299728393555,disc loss=0.43083974719047546, {hms_string(epoch_elapsed)}
# Epoch 246, gen loss=4.824655532836914,disc loss=0.3497184216976166, {hms_string(epoch_elapsed)}
# Epoch 247, gen loss=4.926335334777832,disc loss=0.3726819157600403, {hms_string(epoch_elapsed)}
# Epoch 248, gen loss=4.997586250305176,disc loss=0.3711715042591095, {hms_string(epoch_elapsed)}
# Epoch 249, gen loss=4.942573070526123,disc loss=0.5560680031776428, {hms_string(epoch_elapsed)}
# Epoch 250, gen loss=4.793298721313477,disc loss=0.365215927362442, {hms_string(epoch_elapsed)}
# Epoch 251, gen loss=4.805816650390625,disc loss=0.35667771100997925, {hms_string(epoch_elapsed)}
# Epoch 252, gen loss=4.828860282897949,disc loss=0.34922876954078674, {hms_string(epoch_elapsed)}
# Epoch 253, gen loss=4.975583076477051,disc loss=0.37318480014801025, {hms_string(epoch_elapsed)}
# Epoch 254, gen loss=5.017726898193359,disc loss=0.33558714389801025, {hms_string(epoch_elapsed)}
# Epoch 255, gen loss=5.112771034240723,disc loss=0.38461601734161377, {hms_string(epoch_elapsed)}
# Epoch 256, gen loss=4.84428071975708,disc loss=0.38505566120147705, {hms_string(epoch_elapsed)}
# Epoch 257, gen loss=5.215806007385254,disc loss=0.37406983971595764, {hms_string(epoch_elapsed)}
# Epoch 258, gen loss=5.115193843841553,disc loss=0.34325656294822693, {hms_string(epoch_elapsed)}
# Epoch 259, gen loss=5.149595260620117,disc loss=0.40630966424942017, {hms_string(epoch_elapsed)}
# Epoch 260, gen loss=5.129352569580078,disc loss=0.3051881492137909, {hms_string(epoch_elapsed)}
# Epoch 261, gen loss=5.075926303863525,disc loss=0.4610040783882141, {hms_string(epoch_elapsed)}
# Epoch 262, gen loss=5.077116966247559,disc loss=0.37279611825942993, {hms_string(epoch_elapsed)}
# Epoch 263, gen loss=5.050551414489746,disc loss=0.37565144896507263, {hms_string(epoch_elapsed)}
# Epoch 264, gen loss=4.988744258880615,disc loss=0.3646984398365021, {hms_string(epoch_elapsed)}
# Epoch 265, gen loss=5.201111316680908,disc loss=0.40279677510261536, {hms_string(epoch_elapsed)}
# Epoch 266, gen loss=5.053074836730957,disc loss=0.3877570629119873, {hms_string(epoch_elapsed)}
# Epoch 267, gen loss=5.082733154296875,disc loss=0.46914392709732056, {hms_string(epoch_elapsed)}
# Epoch 268, gen loss=5.140024662017822,disc loss=0.3864901661872864, {hms_string(epoch_elapsed)}
# Epoch 269, gen loss=5.172348499298096,disc loss=0.33532917499542236, {hms_string(epoch_elapsed)}
# Epoch 270, gen loss=5.147510051727295,disc loss=0.35606101155281067, {hms_string(epoch_elapsed)}
# Epoch 271, gen loss=5.1960344314575195,disc loss=0.4005466401576996, {hms_string(epoch_elapsed)}
# Epoch 272, gen loss=5.1923508644104,disc loss=0.3634141981601715, {hms_string(epoch_elapsed)}
# Epoch 273, gen loss=5.041781902313232,disc loss=0.3889811336994171, {hms_string(epoch_elapsed)}
# Epoch 274, gen loss=5.2004547119140625,disc loss=0.41359400749206543, {hms_string(epoch_elapsed)}
# Epoch 275, gen loss=5.198638439178467,disc loss=0.28847602009773254, {hms_string(epoch_elapsed)}
# Epoch 276, gen loss=5.0284223556518555,disc loss=0.39310169219970703, {hms_string(epoch_elapsed)}
# Epoch 277, gen loss=5.083960056304932,disc loss=0.42162811756134033, {hms_string(epoch_elapsed)}
# Epoch 278, gen loss=5.149251461029053,disc loss=0.2813994586467743, {hms_string(epoch_elapsed)}
# Epoch 279, gen loss=5.253820896148682,disc loss=0.3061954379081726, {hms_string(epoch_elapsed)}
# Epoch 280, gen loss=5.286507606506348,disc loss=0.3582545220851898, {hms_string(epoch_elapsed)}
# Epoch 281, gen loss=5.3154520988464355,disc loss=0.2888890504837036, {hms_string(epoch_elapsed)}
# Epoch 282, gen loss=5.525514602661133,disc loss=0.2857408821582794, {hms_string(epoch_elapsed)}
# Epoch 283, gen loss=5.322414875030518,disc loss=0.32754477858543396, {hms_string(epoch_elapsed)}
# Epoch 284, gen loss=5.4952545166015625,disc loss=0.34034043550491333, {hms_string(epoch_elapsed)}
# Epoch 285, gen loss=5.397435188293457,disc loss=0.3831758201122284, {hms_string(epoch_elapsed)}
# Epoch 286, gen loss=5.2868123054504395,disc loss=0.3591075539588928, {hms_string(epoch_elapsed)}
# Epoch 287, gen loss=5.291925430297852,disc loss=0.40317121148109436, {hms_string(epoch_elapsed)}
# Epoch 288, gen loss=5.3445634841918945,disc loss=0.36491110920906067, {hms_string(epoch_elapsed)}
# Epoch 289, gen loss=5.374319553375244,disc loss=0.2980802357196808, {hms_string(epoch_elapsed)}
# Epoch 290, gen loss=5.295736312866211,disc loss=0.38085874915122986, {hms_string(epoch_elapsed)}
# Epoch 291, gen loss=5.419659614562988,disc loss=0.3505461513996124, {hms_string(epoch_elapsed)}
# Epoch 292, gen loss=5.356533527374268,disc loss=0.34463047981262207, {hms_string(epoch_elapsed)}
# Epoch 293, gen loss=5.414024829864502,disc loss=0.30030524730682373, {hms_string(epoch_elapsed)}
# Epoch 294, gen loss=5.5186262130737305,disc loss=0.3553171753883362, {hms_string(epoch_elapsed)}
# Epoch 295, gen loss=5.3933610916137695,disc loss=0.3374781906604767, {hms_string(epoch_elapsed)}
# Epoch 296, gen loss=5.459501266479492,disc loss=0.29176026582717896, {hms_string(epoch_elapsed)}
# Epoch 297, gen loss=5.352287769317627,disc loss=0.3175594210624695, {hms_string(epoch_elapsed)}
# Epoch 298, gen loss=5.404560089111328,disc loss=0.45404472947120667, {hms_string(epoch_elapsed)}
# Epoch 299, gen loss=5.646933555603027,disc loss=0.4537600576877594, {hms_string(epoch_elapsed)}
# Epoch 300, gen loss=5.492025375366211,disc loss=0.3380529582500458, {hms_string(epoch_elapsed)}
# Epoch 301, gen loss=5.400491714477539,disc loss=0.31115448474884033, {hms_string(epoch_elapsed)}
# Epoch 302, gen loss=5.672876834869385,disc loss=0.3839244842529297, {hms_string(epoch_elapsed)}
# Epoch 303, gen loss=5.559820652008057,disc loss=0.2682119309902191, {hms_string(epoch_elapsed)}
# Epoch 304, gen loss=5.623142719268799,disc loss=0.4254496991634369, {hms_string(epoch_elapsed)}
# Epoch 305, gen loss=5.496513843536377,disc loss=0.26027047634124756, {hms_string(epoch_elapsed)}
# Epoch 306, gen loss=5.605966567993164,disc loss=0.35245805978775024, {hms_string(epoch_elapsed)}
# Epoch 307, gen loss=5.524959087371826,disc loss=0.3263252079486847, {hms_string(epoch_elapsed)}
# Epoch 308, gen loss=5.574145793914795,disc loss=0.3580307364463806, {hms_string(epoch_elapsed)}
# Epoch 309, gen loss=5.586074352264404,disc loss=0.3141854405403137, {hms_string(epoch_elapsed)}
# Epoch 310, gen loss=5.60126256942749,disc loss=0.3023199141025543, {hms_string(epoch_elapsed)}
# Epoch 311, gen loss=5.643176555633545,disc loss=0.29478853940963745, {hms_string(epoch_elapsed)}
# Epoch 312, gen loss=5.517160892486572,disc loss=0.3170205056667328, {hms_string(epoch_elapsed)}
# Epoch 313, gen loss=5.800251007080078,disc loss=0.4255252182483673, {hms_string(epoch_elapsed)}
# Epoch 314, gen loss=5.848327159881592,disc loss=0.35943058133125305, {hms_string(epoch_elapsed)}
# Epoch 315, gen loss=5.567105293273926,disc loss=0.2867860496044159, {hms_string(epoch_elapsed)}
# Epoch 316, gen loss=5.64886474609375,disc loss=0.3697529137134552, {hms_string(epoch_elapsed)}
# Epoch 317, gen loss=5.57351541519165,disc loss=0.316954642534256, {hms_string(epoch_elapsed)}
# Epoch 318, gen loss=5.648869514465332,disc loss=0.31002306938171387, {hms_string(epoch_elapsed)}
# Epoch 319, gen loss=5.698107719421387,disc loss=0.3288082182407379, {hms_string(epoch_elapsed)}
# Epoch 320, gen loss=5.628384113311768,disc loss=0.39150622487068176, {hms_string(epoch_elapsed)}
# Epoch 321, gen loss=5.715119361877441,disc loss=0.27011311054229736, {hms_string(epoch_elapsed)}
# Epoch 322, gen loss=5.594336986541748,disc loss=0.3497524559497833, {hms_string(epoch_elapsed)}
# Epoch 323, gen loss=5.631185054779053,disc loss=0.3734394907951355, {hms_string(epoch_elapsed)}
# Epoch 324, gen loss=5.54125452041626,disc loss=0.3495705723762512, {hms_string(epoch_elapsed)}
# Epoch 325, gen loss=5.701354026794434,disc loss=0.35709095001220703, {hms_string(epoch_elapsed)}
# Epoch 326, gen loss=5.635117530822754,disc loss=0.2968834638595581, {hms_string(epoch_elapsed)}
# Epoch 327, gen loss=5.63991117477417,disc loss=0.3372271955013275, {hms_string(epoch_elapsed)}
# Epoch 328, gen loss=5.920227527618408,disc loss=0.384846031665802, {hms_string(epoch_elapsed)}
# Epoch 329, gen loss=5.79555082321167,disc loss=0.3025224804878235, {hms_string(epoch_elapsed)}
# Epoch 330, gen loss=5.773446083068848,disc loss=0.32727184891700745, {hms_string(epoch_elapsed)}
# Epoch 331, gen loss=5.797239780426025,disc loss=0.32698696851730347, {hms_string(epoch_elapsed)}
# Epoch 332, gen loss=5.836839199066162,disc loss=0.27833616733551025, {hms_string(epoch_elapsed)}
# Epoch 333, gen loss=5.661525726318359,disc loss=0.27262061834335327, {hms_string(epoch_elapsed)}
# Epoch 334, gen loss=6.0019378662109375,disc loss=0.26791149377822876, {hms_string(epoch_elapsed)}
# Epoch 335, gen loss=5.518600940704346,disc loss=0.34031838178634644, {hms_string(epoch_elapsed)}
# Epoch 336, gen loss=5.817326068878174,disc loss=0.3120351731777191, {hms_string(epoch_elapsed)}
# Epoch 337, gen loss=6.096614360809326,disc loss=0.3107357621192932, {hms_string(epoch_elapsed)}
# Epoch 338, gen loss=5.819682598114014,disc loss=0.28554368019104004, {hms_string(epoch_elapsed)}
# Epoch 339, gen loss=5.74846887588501,disc loss=0.29047468304634094, {hms_string(epoch_elapsed)}
# Epoch 340, gen loss=5.901317119598389,disc loss=0.24532344937324524, {hms_string(epoch_elapsed)}
# Epoch 341, gen loss=5.999841213226318,disc loss=0.26422563195228577, {hms_string(epoch_elapsed)}
# Epoch 342, gen loss=5.933138847351074,disc loss=0.3574773073196411, {hms_string(epoch_elapsed)}
# Epoch 343, gen loss=6.256947040557861,disc loss=0.3757143020629883, {hms_string(epoch_elapsed)}
# Epoch 344, gen loss=6.065046787261963,disc loss=0.3360626697540283, {hms_string(epoch_elapsed)}
# Epoch 345, gen loss=5.935869216918945,disc loss=0.2414114773273468, {hms_string(epoch_elapsed)}
# Epoch 346, gen loss=6.131983280181885,disc loss=0.24149636924266815, {hms_string(epoch_elapsed)}
# Epoch 347, gen loss=6.082580089569092,disc loss=0.30726510286331177, {hms_string(epoch_elapsed)}
# Epoch 348, gen loss=6.220767974853516,disc loss=0.39229023456573486, {hms_string(epoch_elapsed)}
# Epoch 349, gen loss=6.010138511657715,disc loss=0.24170666933059692, {hms_string(epoch_elapsed)}
# Epoch 350, gen loss=5.8604512214660645,disc loss=0.4042406976222992, {hms_string(epoch_elapsed)}
# Epoch 351, gen loss=6.0067548751831055,disc loss=0.23027798533439636, {hms_string(epoch_elapsed)}
# Epoch 352, gen loss=5.950140476226807,disc loss=0.27322953939437866, {hms_string(epoch_elapsed)}
# Epoch 353, gen loss=6.188900947570801,disc loss=0.32902634143829346, {hms_string(epoch_elapsed)}
# Epoch 354, gen loss=6.030895709991455,disc loss=0.26136597990989685, {hms_string(epoch_elapsed)}
# Epoch 355, gen loss=6.188826084136963,disc loss=0.25026440620422363, {hms_string(epoch_elapsed)}
# Epoch 356, gen loss=6.126389026641846,disc loss=0.23474496603012085, {hms_string(epoch_elapsed)}
# Epoch 357, gen loss=6.274346828460693,disc loss=0.3173719644546509, {hms_string(epoch_elapsed)}
# Epoch 358, gen loss=6.087533473968506,disc loss=0.27356648445129395, {hms_string(epoch_elapsed)}
# Epoch 359, gen loss=6.1327056884765625,disc loss=0.2808314561843872, {hms_string(epoch_elapsed)}
# Epoch 360, gen loss=6.126038074493408,disc loss=0.2741415500640869, {hms_string(epoch_elapsed)}
# Epoch 361, gen loss=6.421578884124756,disc loss=0.3375921845436096, {hms_string(epoch_elapsed)}
# Epoch 362, gen loss=6.281445503234863,disc loss=0.32345592975616455, {hms_string(epoch_elapsed)}
# Epoch 363, gen loss=6.02439022064209,disc loss=0.2795686721801758, {hms_string(epoch_elapsed)}
# Epoch 364, gen loss=6.22813606262207,disc loss=0.2729484736919403, {hms_string(epoch_elapsed)}
# Epoch 365, gen loss=6.155000686645508,disc loss=0.2779899537563324, {hms_string(epoch_elapsed)}
# Epoch 366, gen loss=6.054839134216309,disc loss=0.30306267738342285, {hms_string(epoch_elapsed)}
# Epoch 367, gen loss=6.1963725090026855,disc loss=0.30418264865875244, {hms_string(epoch_elapsed)}
# Epoch 368, gen loss=6.149652004241943,disc loss=0.2536439299583435, {hms_string(epoch_elapsed)}
# Epoch 369, gen loss=6.403563976287842,disc loss=0.23755396902561188, {hms_string(epoch_elapsed)}
# Epoch 370, gen loss=6.254617214202881,disc loss=0.23711036145687103, {hms_string(epoch_elapsed)}
# Epoch 371, gen loss=6.463735103607178,disc loss=0.25137901306152344, {hms_string(epoch_elapsed)}
# Epoch 372, gen loss=6.411757946014404,disc loss=0.3704148232936859, {hms_string(epoch_elapsed)}
# Epoch 373, gen loss=6.32634973526001,disc loss=0.2970578968524933, {hms_string(epoch_elapsed)}
# Epoch 374, gen loss=6.129971027374268,disc loss=0.3063426613807678, {hms_string(epoch_elapsed)}
# Epoch 375, gen loss=6.205484390258789,disc loss=0.31483784317970276, {hms_string(epoch_elapsed)}
# Epoch 376, gen loss=6.382288455963135,disc loss=0.32026270031929016, {hms_string(epoch_elapsed)}
# Epoch 377, gen loss=6.32540225982666,disc loss=0.37346044182777405, {hms_string(epoch_elapsed)}
# Epoch 378, gen loss=6.2083821296691895,disc loss=0.30471253395080566, {hms_string(epoch_elapsed)}
# Epoch 379, gen loss=6.263675212860107,disc loss=0.2739826440811157, {hms_string(epoch_elapsed)}
# Epoch 380, gen loss=6.419504165649414,disc loss=0.25166410207748413, {hms_string(epoch_elapsed)}
# Epoch 381, gen loss=6.182947635650635,disc loss=0.2689858675003052, {hms_string(epoch_elapsed)}
# Epoch 382, gen loss=6.2271575927734375,disc loss=0.2560523450374603, {hms_string(epoch_elapsed)}
# Epoch 383, gen loss=6.182871341705322,disc loss=0.2618061602115631, {hms_string(epoch_elapsed)}
# Epoch 384, gen loss=6.346293926239014,disc loss=0.2553815543651581, {hms_string(epoch_elapsed)}
# Epoch 385, gen loss=6.484012126922607,disc loss=0.22067800164222717, {hms_string(epoch_elapsed)}
# Epoch 386, gen loss=6.499135494232178,disc loss=0.25751984119415283, {hms_string(epoch_elapsed)}
# Epoch 387, gen loss=6.487091064453125,disc loss=0.18120287358760834, {hms_string(epoch_elapsed)}
# Epoch 388, gen loss=6.242055892944336,disc loss=0.31167131662368774, {hms_string(epoch_elapsed)}
# Epoch 389, gen loss=6.437016487121582,disc loss=0.277111679315567, {hms_string(epoch_elapsed)}
# Epoch 390, gen loss=6.568752765655518,disc loss=0.28806450963020325, {hms_string(epoch_elapsed)}
# Epoch 391, gen loss=6.33201265335083,disc loss=0.2913931906223297, {hms_string(epoch_elapsed)}
# Epoch 392, gen loss=6.326739311218262,disc loss=0.28083375096321106, {hms_string(epoch_elapsed)}
# Epoch 393, gen loss=6.371171951293945,disc loss=0.3162291944026947, {hms_string(epoch_elapsed)}
# Epoch 394, gen loss=6.709795951843262,disc loss=0.28339794278144836, {hms_string(epoch_elapsed)}
# Epoch 395, gen loss=6.282039165496826,disc loss=0.28022485971450806, {hms_string(epoch_elapsed)}
# Epoch 396, gen loss=6.363982677459717,disc loss=0.2353666126728058, {hms_string(epoch_elapsed)}
# Epoch 397, gen loss=6.453135967254639,disc loss=0.22314859926700592, {hms_string(epoch_elapsed)}
# Epoch 398, gen loss=6.623176097869873,disc loss=0.24003955721855164, {hms_string(epoch_elapsed)}
# Epoch 399, gen loss=6.570494651794434,disc loss=0.23990681767463684, {hms_string(epoch_elapsed)}
# Epoch 400, gen loss=6.706741809844971,disc loss=0.18715424835681915, {hms_string(epoch_elapsed)}
# Epoch 401, gen loss=6.744865894317627,disc loss=0.26307737827301025, {hms_string(epoch_elapsed)}
# Epoch 402, gen loss=6.753085613250732,disc loss=0.31041109561920166, {hms_string(epoch_elapsed)}
# Epoch 403, gen loss=6.5923752784729,disc loss=0.3756423592567444, {hms_string(epoch_elapsed)}
# Epoch 404, gen loss=6.124931812286377,disc loss=0.27996987104415894, {hms_string(epoch_elapsed)}
# Epoch 405, gen loss=6.479588508605957,disc loss=0.21145443618297577, {hms_string(epoch_elapsed)}
# Epoch 406, gen loss=6.634181022644043,disc loss=0.2643488645553589, {hms_string(epoch_elapsed)}
# Epoch 407, gen loss=6.598867416381836,disc loss=0.20471206307411194, {hms_string(epoch_elapsed)}
# Epoch 408, gen loss=6.44399881362915,disc loss=0.277641624212265, {hms_string(epoch_elapsed)}
# Epoch 409, gen loss=6.598715782165527,disc loss=0.2574239671230316, {hms_string(epoch_elapsed)}
# Epoch 410, gen loss=6.329699516296387,disc loss=0.2936471700668335, {hms_string(epoch_elapsed)}
# Epoch 411, gen loss=6.529613494873047,disc loss=0.2715165317058563, {hms_string(epoch_elapsed)}
# Epoch 412, gen loss=6.5524678230285645,disc loss=0.2563709020614624, {hms_string(epoch_elapsed)}
# Epoch 413, gen loss=6.462536334991455,disc loss=0.30874499678611755, {hms_string(epoch_elapsed)}
# Epoch 414, gen loss=6.904969215393066,disc loss=0.24031150341033936, {hms_string(epoch_elapsed)}
# Epoch 415, gen loss=6.659901142120361,disc loss=0.22856329381465912, {hms_string(epoch_elapsed)}
# Epoch 416, gen loss=6.708993911743164,disc loss=0.213703453540802, {hms_string(epoch_elapsed)}
# Epoch 417, gen loss=6.6119890213012695,disc loss=0.2332073599100113, {hms_string(epoch_elapsed)}
# Epoch 418, gen loss=6.677213668823242,disc loss=0.3787190020084381, {hms_string(epoch_elapsed)}
# Epoch 419, gen loss=6.672669887542725,disc loss=0.25931045413017273, {hms_string(epoch_elapsed)}
# Epoch 420, gen loss=6.772448539733887,disc loss=0.18514806032180786, {hms_string(epoch_elapsed)}
# Epoch 421, gen loss=6.780378341674805,disc loss=0.239525705575943, {hms_string(epoch_elapsed)}
# Epoch 422, gen loss=6.867755889892578,disc loss=0.24417947232723236, {hms_string(epoch_elapsed)}
# Epoch 423, gen loss=7.020330429077148,disc loss=0.21777845919132233, {hms_string(epoch_elapsed)}
# Epoch 424, gen loss=6.655392169952393,disc loss=0.38794857263565063, {hms_string(epoch_elapsed)}
# Epoch 425, gen loss=6.907081127166748,disc loss=0.19720178842544556, {hms_string(epoch_elapsed)}
# Epoch 426, gen loss=6.892889022827148,disc loss=0.2486293613910675, {hms_string(epoch_elapsed)}
# Epoch 427, gen loss=6.872864723205566,disc loss=0.17849566042423248, {hms_string(epoch_elapsed)}
# Epoch 428, gen loss=6.610413074493408,disc loss=0.2565450370311737, {hms_string(epoch_elapsed)}
# Epoch 429, gen loss=6.919930934906006,disc loss=0.18791814148426056, {hms_string(epoch_elapsed)}
# Epoch 430, gen loss=6.944293975830078,disc loss=0.3379698097705841, {hms_string(epoch_elapsed)}
# Epoch 431, gen loss=6.788626194000244,disc loss=0.22461190819740295, {hms_string(epoch_elapsed)}
# Epoch 432, gen loss=6.834456443786621,disc loss=0.18596151471138, {hms_string(epoch_elapsed)}
# Epoch 433, gen loss=6.965336799621582,disc loss=0.18529675900936127, {hms_string(epoch_elapsed)}
# Epoch 434, gen loss=6.668774604797363,disc loss=0.310792475938797, {hms_string(epoch_elapsed)}
# Epoch 435, gen loss=6.851871013641357,disc loss=0.2329772710800171, {hms_string(epoch_elapsed)}
# Epoch 436, gen loss=7.111922740936279,disc loss=0.21900436282157898, {hms_string(epoch_elapsed)}
# Epoch 437, gen loss=6.821272850036621,disc loss=0.23290057480335236, {hms_string(epoch_elapsed)}
# Epoch 438, gen loss=7.121633529663086,disc loss=0.2671973705291748, {hms_string(epoch_elapsed)}
# Epoch 439, gen loss=6.8035383224487305,disc loss=0.21170631051063538, {hms_string(epoch_elapsed)}
# Epoch 440, gen loss=7.015055179595947,disc loss=0.2854880392551422, {hms_string(epoch_elapsed)}
# Epoch 441, gen loss=6.685997486114502,disc loss=0.19963712990283966, {hms_string(epoch_elapsed)}
# Epoch 442, gen loss=6.935423851013184,disc loss=0.2400236427783966, {hms_string(epoch_elapsed)}
# Epoch 443, gen loss=7.03949499130249,disc loss=0.18360678851604462, {hms_string(epoch_elapsed)}
# Epoch 444, gen loss=7.100404739379883,disc loss=0.3533022999763489, {hms_string(epoch_elapsed)}
# Epoch 445, gen loss=6.920994758605957,disc loss=0.21283921599388123, {hms_string(epoch_elapsed)}
# Epoch 446, gen loss=6.978906631469727,disc loss=0.2457808405160904, {hms_string(epoch_elapsed)}
# Epoch 447, gen loss=6.975750923156738,disc loss=0.34527885913848877, {hms_string(epoch_elapsed)}
# Epoch 448, gen loss=6.98676061630249,disc loss=0.19686152040958405, {hms_string(epoch_elapsed)}
# Epoch 449, gen loss=7.007633209228516,disc loss=0.18248721957206726, {hms_string(epoch_elapsed)}
# Epoch 450, gen loss=6.780384540557861,disc loss=0.19660334289073944, {hms_string(epoch_elapsed)}
# Epoch 451, gen loss=7.042448997497559,disc loss=0.22984634339809418, {hms_string(epoch_elapsed)}
# Epoch 452, gen loss=6.933529853820801,disc loss=0.22559869289398193, {hms_string(epoch_elapsed)}
# Epoch 453, gen loss=7.005589485168457,disc loss=0.2952067255973816, {hms_string(epoch_elapsed)}
# Epoch 454, gen loss=7.266425609588623,disc loss=0.349599152803421, {hms_string(epoch_elapsed)}
# Epoch 455, gen loss=7.0978498458862305,disc loss=0.3144359886646271, {hms_string(epoch_elapsed)}
# Epoch 456, gen loss=6.847240447998047,disc loss=0.20509284734725952, {hms_string(epoch_elapsed)}
# Epoch 457, gen loss=6.875357151031494,disc loss=0.25865909457206726, {hms_string(epoch_elapsed)}
# Epoch 458, gen loss=7.131155014038086,disc loss=0.25649765133857727, {hms_string(epoch_elapsed)}
# Epoch 459, gen loss=6.736809730529785,disc loss=0.21714413166046143, {hms_string(epoch_elapsed)}
# Epoch 460, gen loss=6.840068340301514,disc loss=0.24013203382492065, {hms_string(epoch_elapsed)}
# Epoch 461, gen loss=7.0530171394348145,disc loss=0.1955186426639557, {hms_string(epoch_elapsed)}
# Epoch 462, gen loss=6.916421890258789,disc loss=0.27144092321395874, {hms_string(epoch_elapsed)}
# Epoch 463, gen loss=7.0601277351379395,disc loss=0.19979926943778992, {hms_string(epoch_elapsed)}
# Epoch 464, gen loss=7.062020301818848,disc loss=0.25503915548324585, {hms_string(epoch_elapsed)}
# Epoch 465, gen loss=7.2813639640808105,disc loss=0.2501436471939087, {hms_string(epoch_elapsed)}
# Epoch 466, gen loss=6.986392021179199,disc loss=0.17945162951946259, {hms_string(epoch_elapsed)}
# Epoch 467, gen loss=7.008160591125488,disc loss=0.18937402963638306, {hms_string(epoch_elapsed)}
# Epoch 468, gen loss=7.117074489593506,disc loss=0.20196974277496338, {hms_string(epoch_elapsed)}
# Epoch 469, gen loss=7.07852840423584,disc loss=0.2556847631931305, {hms_string(epoch_elapsed)}
# Epoch 470, gen loss=6.944021701812744,disc loss=0.35957345366477966, {hms_string(epoch_elapsed)}
# Epoch 471, gen loss=7.183062553405762,disc loss=0.23881085216999054, {hms_string(epoch_elapsed)}
# Epoch 472, gen loss=7.154835224151611,disc loss=0.23236466944217682, {hms_string(epoch_elapsed)}
# Epoch 473, gen loss=7.181134223937988,disc loss=0.19914831221103668, {hms_string(epoch_elapsed)}
# Epoch 474, gen loss=7.039876937866211,disc loss=0.20274344086647034, {hms_string(epoch_elapsed)}
# Epoch 475, gen loss=7.408116340637207,disc loss=0.2641379237174988, {hms_string(epoch_elapsed)}
# Epoch 476, gen loss=7.24469518661499,disc loss=0.16321192681789398, {hms_string(epoch_elapsed)}
# Epoch 477, gen loss=7.50171422958374,disc loss=0.26497748494148254, {hms_string(epoch_elapsed)}
# Epoch 478, gen loss=7.181011199951172,disc loss=0.25351497530937195, {hms_string(epoch_elapsed)}
# Epoch 479, gen loss=7.2491254806518555,disc loss=0.2158203125, {hms_string(epoch_elapsed)}
# Epoch 480, gen loss=7.329940319061279,disc loss=0.20566284656524658, {hms_string(epoch_elapsed)}
# Epoch 481, gen loss=7.051457405090332,disc loss=0.180375874042511, {hms_string(epoch_elapsed)}
# Epoch 482, gen loss=7.349580764770508,disc loss=0.1766042709350586, {hms_string(epoch_elapsed)}
# Epoch 483, gen loss=7.239224433898926,disc loss=0.1606653779745102, {hms_string(epoch_elapsed)}
# Epoch 484, gen loss=7.582311153411865,disc loss=0.25486162304878235, {hms_string(epoch_elapsed)}
# Epoch 485, gen loss=7.228076457977295,disc loss=0.2420686036348343, {hms_string(epoch_elapsed)}
# Epoch 486, gen loss=7.304612636566162,disc loss=0.2809721827507019, {hms_string(epoch_elapsed)}
# Epoch 487, gen loss=7.22606086730957,disc loss=0.30289050936698914, {hms_string(epoch_elapsed)}
# Epoch 488, gen loss=7.209941864013672,disc loss=0.20685788989067078, {hms_string(epoch_elapsed)}
# Epoch 489, gen loss=7.117304801940918,disc loss=0.19928601384162903, {hms_string(epoch_elapsed)}
# Epoch 490, gen loss=7.192480564117432,disc loss=0.2728272080421448, {hms_string(epoch_elapsed)}
# Epoch 491, gen loss=7.251068115234375,disc loss=0.16143332421779633, {hms_string(epoch_elapsed)}
# Epoch 492, gen loss=7.240231513977051,disc loss=0.2128731906414032, {hms_string(epoch_elapsed)}
# Epoch 493, gen loss=7.017701625823975,disc loss=0.21846142411231995, {hms_string(epoch_elapsed)}
# Epoch 494, gen loss=7.425267696380615,disc loss=0.2602139413356781, {hms_string(epoch_elapsed)}
# Epoch 495, gen loss=7.41365909576416,disc loss=0.22647124528884888, {hms_string(epoch_elapsed)}
# Epoch 496, gen loss=7.392067909240723,disc loss=0.17689764499664307, {hms_string(epoch_elapsed)}
# Epoch 497, gen loss=7.247171878814697,disc loss=0.2148149162530899, {hms_string(epoch_elapsed)}
# Epoch 498, gen loss=7.104761123657227,disc loss=0.27514052391052246, {hms_string(epoch_elapsed)}
# ...
# Epoch 1763, gen loss=11.0460786819458,disc loss=0.1559295803308487, {hms_string(epoch_elapsed)}
# Epoch 1764, gen loss=11.206942558288574,disc loss=0.15322844684123993, {hms_string(epoch_elapsed)}
# Epoch 1765, gen loss=11.274284362792969,disc loss=0.12119290977716446, {hms_string(epoch_elapsed)}
# Epoch 1766, gen loss=11.037064552307129,disc loss=0.12216808646917343, {hms_string(epoch_elapsed)}
# Epoch 1767, gen loss=11.334343910217285,disc loss=0.1387598067522049, {hms_string(epoch_elapsed)}
# Epoch 1768, gen loss=11.634929656982422,disc loss=0.1160525307059288, {hms_string(epoch_elapsed)}
# Epoch 1769, gen loss=11.382477760314941,disc loss=0.11361096054315567, {hms_string(epoch_elapsed)}
# Epoch 1770, gen loss=10.79721736907959,disc loss=0.09217911958694458, {hms_string(epoch_elapsed)}
# Epoch 1771, gen loss=11.260077476501465,disc loss=0.10672694444656372, {hms_string(epoch_elapsed)}
# Epoch 1772, gen loss=11.183016777038574,disc loss=0.12618769705295563, {hms_string(epoch_elapsed)}
# Epoch 1773, gen loss=11.32004451751709,disc loss=0.1207057386636734, {hms_string(epoch_elapsed)}
# Epoch 1774, gen loss=11.536186218261719,disc loss=0.14649918675422668, {hms_string(epoch_elapsed)}
# Epoch 1775, gen loss=11.955399513244629,disc loss=0.1167970672249794, {hms_string(epoch_elapsed)}
# Epoch 1776, gen loss=11.462785720825195,disc loss=0.09423970431089401, {hms_string(epoch_elapsed)}
# Epoch 1777, gen loss=11.284424781799316,disc loss=0.14117570221424103, {hms_string(epoch_elapsed)}
# Epoch 1778, gen loss=11.427667617797852,disc loss=0.13459262251853943, {hms_string(epoch_elapsed)}
# Epoch 1779, gen loss=11.695609092712402,disc loss=0.11813261359930038, {hms_string(epoch_elapsed)}
# Epoch 1780, gen loss=11.112679481506348,disc loss=0.16427449882030487, {hms_string(epoch_elapsed)}
# Epoch 1781, gen loss=11.438486099243164,disc loss=0.1363249272108078, {hms_string(epoch_elapsed)}
# Epoch 1782, gen loss=11.362506866455078,disc loss=0.11630796641111374, {hms_string(epoch_elapsed)}
# Epoch 1783, gen loss=11.203746795654297,disc loss=0.09275795519351959, {hms_string(epoch_elapsed)}
# Epoch 1784, gen loss=11.12517261505127,disc loss=0.10340754687786102, {hms_string(epoch_elapsed)}
# Epoch 1785, gen loss=11.687119483947754,disc loss=0.1045994758605957, {hms_string(epoch_elapsed)}
# Epoch 1786, gen loss=11.334412574768066,disc loss=0.16014088690280914, {hms_string(epoch_elapsed)}
# Epoch 1787, gen loss=11.197744369506836,disc loss=0.10177622735500336, {hms_string(epoch_elapsed)}
# Epoch 1788, gen loss=11.731578826904297,disc loss=0.12818534672260284, {hms_string(epoch_elapsed)}
# Epoch 1789, gen loss=11.514707565307617,disc loss=0.12744952738285065, {hms_string(epoch_elapsed)}
# Epoch 1790, gen loss=11.551881790161133,disc loss=0.12456068396568298, {hms_string(epoch_elapsed)}
# Epoch 1791, gen loss=11.962303161621094,disc loss=0.08996346592903137, {hms_string(epoch_elapsed)}
# Epoch 1792, gen loss=11.170722007751465,disc loss=0.12556546926498413, {hms_string(epoch_elapsed)}
# Epoch 1793, gen loss=11.465932846069336,disc loss=0.14548003673553467, {hms_string(epoch_elapsed)}
# Epoch 1794, gen loss=11.857735633850098,disc loss=0.12488321959972382, {hms_string(epoch_elapsed)}
# Epoch 1795, gen loss=11.062920570373535,disc loss=0.12218921631574631, {hms_string(epoch_elapsed)}
# Epoch 1796, gen loss=11.438111305236816,disc loss=0.17179885506629944, {hms_string(epoch_elapsed)}
# Epoch 1797, gen loss=11.477527618408203,disc loss=0.10516611486673355, {hms_string(epoch_elapsed)}
# Epoch 1798, gen loss=11.593184471130371,disc loss=0.11250371485948563, {hms_string(epoch_elapsed)}
# Epoch 1799, gen loss=11.38278579711914,disc loss=0.14639852941036224, {hms_string(epoch_elapsed)}
# Epoch 1800, gen loss=11.14487075805664,disc loss=0.10601473599672318, {hms_string(epoch_elapsed)}
# Epoch 1801, gen loss=11.625716209411621,disc loss=0.14055316150188446, {hms_string(epoch_elapsed)}
# Epoch 1802, gen loss=11.849145889282227,disc loss=0.1521904170513153, {hms_string(epoch_elapsed)}
# Epoch 1803, gen loss=11.221885681152344,disc loss=0.12089406698942184, {hms_string(epoch_elapsed)}
# Epoch 1804, gen loss=11.556380271911621,disc loss=0.130183145403862, {hms_string(epoch_elapsed)}
# Epoch 1805, gen loss=11.082221031188965,disc loss=0.09544044733047485, {hms_string(epoch_elapsed)}
# Epoch 1806, gen loss=10.989119529724121,disc loss=0.13286852836608887, {hms_string(epoch_elapsed)}
# Epoch 1807, gen loss=11.129009246826172,disc loss=0.11480669677257538, {hms_string(epoch_elapsed)}
# Epoch 1808, gen loss=11.573444366455078,disc loss=0.14719712734222412, {hms_string(epoch_elapsed)}
# Epoch 1809, gen loss=11.366275787353516,disc loss=0.10143299400806427, {hms_string(epoch_elapsed)}
# Epoch 1810, gen loss=11.03211498260498,disc loss=0.13920821249485016, {hms_string(epoch_elapsed)}
# Epoch 1811, gen loss=11.075335502624512,disc loss=0.12040288746356964, {hms_string(epoch_elapsed)}
# Epoch 1812, gen loss=11.496321678161621,disc loss=0.1372789740562439, {hms_string(epoch_elapsed)}
# Epoch 1813, gen loss=11.164589881896973,disc loss=0.13853344321250916, {hms_string(epoch_elapsed)}
# Epoch 1814, gen loss=11.522784233093262,disc loss=0.15142597258090973, {hms_string(epoch_elapsed)}
# Epoch 1815, gen loss=11.107756614685059,disc loss=0.13828502595424652, {hms_string(epoch_elapsed)}
# Epoch 1816, gen loss=10.842008590698242,disc loss=0.08070097118616104, {hms_string(epoch_elapsed)}
# Epoch 1817, gen loss=11.04232406616211,disc loss=0.10506043583154678, {hms_string(epoch_elapsed)}
# Epoch 1818, gen loss=11.867612838745117,disc loss=0.1231134831905365, {hms_string(epoch_elapsed)}
# Epoch 1819, gen loss=11.406774520874023,disc loss=0.15035884082317352, {hms_string(epoch_elapsed)}
# Epoch 1820, gen loss=11.46492862701416,disc loss=0.10583558678627014, {hms_string(epoch_elapsed)}
# Epoch 1821, gen loss=11.29435920715332,disc loss=0.10253620892763138, {hms_string(epoch_elapsed)}
# Epoch 1822, gen loss=11.428221702575684,disc loss=0.11142776906490326, {hms_string(epoch_elapsed)}
# Epoch 1823, gen loss=11.544625282287598,disc loss=0.11506183445453644, {hms_string(epoch_elapsed)}
# Epoch 1824, gen loss=12.229108810424805,disc loss=0.17140506207942963, {hms_string(epoch_elapsed)}
# Epoch 1825, gen loss=11.796801567077637,disc loss=0.11219707876443863, {hms_string(epoch_elapsed)}
# Epoch 1826, gen loss=11.322441101074219,disc loss=0.12198156118392944, {hms_string(epoch_elapsed)}
# Epoch 1827, gen loss=10.977429389953613,disc loss=0.133966863155365, {hms_string(epoch_elapsed)}
# Epoch 1828, gen loss=11.556050300598145,disc loss=0.09133372455835342, {hms_string(epoch_elapsed)}
# Epoch 1829, gen loss=11.385254859924316,disc loss=0.08959423750638962, {hms_string(epoch_elapsed)}
# Epoch 1830, gen loss=11.185561180114746,disc loss=0.11226331442594528, {hms_string(epoch_elapsed)}
# Epoch 1831, gen loss=11.644051551818848,disc loss=0.12664872407913208, {hms_string(epoch_elapsed)}
# Epoch 1832, gen loss=11.603461265563965,disc loss=0.16216644644737244, {hms_string(epoch_elapsed)}
# Epoch 1833, gen loss=10.762673377990723,disc loss=0.1393524408340454, {hms_string(epoch_elapsed)}
# Epoch 1834, gen loss=11.523453712463379,disc loss=0.11267274618148804, {hms_string(epoch_elapsed)}
# Epoch 1835, gen loss=11.696949005126953,disc loss=0.12480595707893372, {hms_string(epoch_elapsed)}
# Epoch 1836, gen loss=11.889481544494629,disc loss=0.12599948048591614, {hms_string(epoch_elapsed)}
# Epoch 1837, gen loss=11.808967590332031,disc loss=0.09428935497999191, {hms_string(epoch_elapsed)}
# Epoch 1838, gen loss=11.56021499633789,disc loss=0.10340626537799835, {hms_string(epoch_elapsed)}
# Epoch 1839, gen loss=11.376646995544434,disc loss=0.10956238955259323, {hms_string(epoch_elapsed)}
# Epoch 1840, gen loss=11.608614921569824,disc loss=0.10175997018814087, {hms_string(epoch_elapsed)}
# Epoch 1841, gen loss=11.060284614562988,disc loss=0.1120830699801445, {hms_string(epoch_elapsed)}
# Epoch 1842, gen loss=11.17064380645752,disc loss=0.1229996606707573, {hms_string(epoch_elapsed)}
# Epoch 1843, gen loss=11.958906173706055,disc loss=0.11987276375293732, {hms_string(epoch_elapsed)}
# Epoch 1844, gen loss=11.149909019470215,disc loss=0.11016838997602463, {hms_string(epoch_elapsed)}
# Epoch 1845, gen loss=12.209583282470703,disc loss=0.11491929739713669, {hms_string(epoch_elapsed)}
# Epoch 1846, gen loss=11.240937232971191,disc loss=0.0896848812699318, {hms_string(epoch_elapsed)}
# Epoch 1847, gen loss=11.2039155960083,disc loss=0.12364400923252106, {hms_string(epoch_elapsed)}
# Epoch 1848, gen loss=11.306437492370605,disc loss=0.12692175805568695, {hms_string(epoch_elapsed)}
# Epoch 1849, gen loss=11.825060844421387,disc loss=0.1378343403339386, {hms_string(epoch_elapsed)}
# Epoch 1850, gen loss=12.10627269744873,disc loss=0.09737095236778259, {hms_string(epoch_elapsed)}
# Epoch 1851, gen loss=11.689079284667969,disc loss=0.11887703090906143, {hms_string(epoch_elapsed)}
# Epoch 1852, gen loss=12.116503715515137,disc loss=0.12808789312839508, {hms_string(epoch_elapsed)}
# Epoch 1853, gen loss=11.494051933288574,disc loss=0.09291745722293854, {hms_string(epoch_elapsed)}
# Epoch 1854, gen loss=11.813925743103027,disc loss=0.10801709443330765, {hms_string(epoch_elapsed)}
# Epoch 1855, gen loss=11.489397048950195,disc loss=0.12892107665538788, {hms_string(epoch_elapsed)}
# Epoch 1856, gen loss=11.600188255310059,disc loss=0.1081555038690567, {hms_string(epoch_elapsed)}
# Epoch 1857, gen loss=11.480232238769531,disc loss=0.11055037379264832, {hms_string(epoch_elapsed)}
# Epoch 1858, gen loss=11.103018760681152,disc loss=0.11760976910591125, {hms_string(epoch_elapsed)}
# Epoch 1859, gen loss=12.044233322143555,disc loss=0.14339560270309448, {hms_string(epoch_elapsed)}
# Epoch 1860, gen loss=11.317342758178711,disc loss=0.19786091148853302, {hms_string(epoch_elapsed)}
# Epoch 1861, gen loss=12.184043884277344,disc loss=0.0988617092370987, {hms_string(epoch_elapsed)}
# Epoch 1862, gen loss=11.797168731689453,disc loss=0.12959355115890503, {hms_string(epoch_elapsed)}
# Epoch 1863, gen loss=11.06384563446045,disc loss=0.12818223237991333, {hms_string(epoch_elapsed)}
# Epoch 1864, gen loss=11.581451416015625,disc loss=0.1383514702320099, {hms_string(epoch_elapsed)}
# Epoch 1865, gen loss=11.89962100982666,disc loss=0.12706100940704346, {hms_string(epoch_elapsed)}
# Epoch 1866, gen loss=11.73595905303955,disc loss=0.09124284982681274, {hms_string(epoch_elapsed)}
# Epoch 1867, gen loss=11.962352752685547,disc loss=0.08027627319097519, {hms_string(epoch_elapsed)}
# Epoch 1868, gen loss=11.621474266052246,disc loss=0.1294754296541214, {hms_string(epoch_elapsed)}
# Epoch 1869, gen loss=11.868878364562988,disc loss=0.16378740966320038, {hms_string(epoch_elapsed)}
# Epoch 1870, gen loss=12.245615005493164,disc loss=0.0963897854089737, {hms_string(epoch_elapsed)}
# Epoch 1871, gen loss=11.829047203063965,disc loss=0.09835494309663773, {hms_string(epoch_elapsed)}
# Epoch 1872, gen loss=11.724454879760742,disc loss=0.17180749773979187, {hms_string(epoch_elapsed)}
# Epoch 1873, gen loss=12.207917213439941,disc loss=0.11563335359096527, {hms_string(epoch_elapsed)}
# Epoch 1874, gen loss=11.498124122619629,disc loss=0.10357612371444702, {hms_string(epoch_elapsed)}
# Epoch 1875, gen loss=10.988188743591309,disc loss=0.11803656816482544, {hms_string(epoch_elapsed)}
# Epoch 1876, gen loss=11.437085151672363,disc loss=0.1290578544139862, {hms_string(epoch_elapsed)}
# Epoch 1877, gen loss=11.322366714477539,disc loss=0.11935050040483475, {hms_string(epoch_elapsed)}
# Epoch 1878, gen loss=11.233441352844238,disc loss=0.15334905683994293, {hms_string(epoch_elapsed)}
# Epoch 1879, gen loss=11.92121696472168,disc loss=0.08594898879528046, {hms_string(epoch_elapsed)}
# Epoch 1880, gen loss=11.334818840026855,disc loss=0.13559767603874207, {hms_string(epoch_elapsed)}
# Epoch 1881, gen loss=11.640863418579102,disc loss=0.11770368367433548, {hms_string(epoch_elapsed)}
# Epoch 1882, gen loss=11.393959045410156,disc loss=0.1397089660167694, {hms_string(epoch_elapsed)}
# Epoch 1883, gen loss=11.738518714904785,disc loss=0.14159545302391052, {hms_string(epoch_elapsed)}
# Epoch 1884, gen loss=11.444374084472656,disc loss=0.16897371411323547, {hms_string(epoch_elapsed)}
# Epoch 1885, gen loss=11.381406784057617,disc loss=0.08755670487880707, {hms_string(epoch_elapsed)}
# Epoch 1886, gen loss=11.9635591506958,disc loss=0.09185469895601273, {hms_string(epoch_elapsed)}
# Epoch 1887, gen loss=11.472288131713867,disc loss=0.0773659199476242, {hms_string(epoch_elapsed)}
# Epoch 1888, gen loss=11.212423324584961,disc loss=0.1041860431432724, {hms_string(epoch_elapsed)}
# Epoch 1889, gen loss=11.754202842712402,disc loss=0.11277342587709427, {hms_string(epoch_elapsed)}
# Epoch 1890, gen loss=11.32480239868164,disc loss=0.1443263590335846, {hms_string(epoch_elapsed)}
# Epoch 1891, gen loss=12.029768943786621,disc loss=0.15145455300807953, {hms_string(epoch_elapsed)}
# Epoch 1892, gen loss=11.062705993652344,disc loss=0.12902112305164337, {hms_string(epoch_elapsed)}
# Epoch 1893, gen loss=11.786969184875488,disc loss=0.14737431704998016, {hms_string(epoch_elapsed)}
# Epoch 1894, gen loss=11.11167049407959,disc loss=0.10565929859876633, {hms_string(epoch_elapsed)}
# Epoch 1895, gen loss=11.540385246276855,disc loss=0.12665964663028717, {hms_string(epoch_elapsed)}
# Epoch 1896, gen loss=11.114116668701172,disc loss=0.1486806571483612, {hms_string(epoch_elapsed)}
# Epoch 1897, gen loss=11.413653373718262,disc loss=0.15156114101409912, {hms_string(epoch_elapsed)}
# Epoch 1898, gen loss=11.602420806884766,disc loss=0.10215260833501816, {hms_string(epoch_elapsed)}
# Epoch 1899, gen loss=12.012785911560059,disc loss=0.11607558280229568, {hms_string(epoch_elapsed)}
# Epoch 1900, gen loss=11.51722240447998,disc loss=0.10963727533817291, {hms_string(epoch_elapsed)}
# Epoch 1901, gen loss=11.130001068115234,disc loss=0.10451196134090424, {hms_string(epoch_elapsed)}
# Epoch 1902, gen loss=11.769574165344238,disc loss=0.1266719549894333, {hms_string(epoch_elapsed)}
# Epoch 1903, gen loss=11.494121551513672,disc loss=0.09750755876302719, {hms_string(epoch_elapsed)}
# Epoch 1904, gen loss=11.456681251525879,disc loss=0.08837679028511047, {hms_string(epoch_elapsed)}
# Epoch 1905, gen loss=11.878568649291992,disc loss=0.08512383699417114, {hms_string(epoch_elapsed)}
# Epoch 1906, gen loss=12.403840065002441,disc loss=0.18096955120563507, {hms_string(epoch_elapsed)}
# Epoch 1907, gen loss=11.76194953918457,disc loss=0.11307650804519653, {hms_string(epoch_elapsed)}
# Epoch 1908, gen loss=11.107666969299316,disc loss=0.13483698666095734, {hms_string(epoch_elapsed)}
# Epoch 1909, gen loss=12.122745513916016,disc loss=0.09706360101699829, {hms_string(epoch_elapsed)}
# Epoch 1910, gen loss=11.674072265625,disc loss=0.16462545096874237, {hms_string(epoch_elapsed)}
# Epoch 1911, gen loss=11.12702465057373,disc loss=0.1344221532344818, {hms_string(epoch_elapsed)}
# Epoch 1912, gen loss=12.013763427734375,disc loss=0.10109125822782516, {hms_string(epoch_elapsed)}
# Epoch 1913, gen loss=11.663614273071289,disc loss=0.13243409991264343, {hms_string(epoch_elapsed)}
# Epoch 1914, gen loss=11.350386619567871,disc loss=0.0763806477189064, {hms_string(epoch_elapsed)}
# Epoch 1915, gen loss=11.63794994354248,disc loss=0.10567808896303177, {hms_string(epoch_elapsed)}
# Epoch 1916, gen loss=11.840036392211914,disc loss=0.11034268885850906, {hms_string(epoch_elapsed)}
# Epoch 1917, gen loss=11.800515174865723,disc loss=0.13113197684288025, {hms_string(epoch_elapsed)}
# Epoch 1918, gen loss=11.50794506072998,disc loss=0.09936673939228058, {hms_string(epoch_elapsed)}
# Epoch 1919, gen loss=11.958757400512695,disc loss=0.12112283706665039, {hms_string(epoch_elapsed)}
# Epoch 1920, gen loss=11.809041023254395,disc loss=0.0919785425066948, {hms_string(epoch_elapsed)}
# Epoch 1921, gen loss=11.964417457580566,disc loss=0.09382081031799316, {hms_string(epoch_elapsed)}
# Epoch 1922, gen loss=11.324861526489258,disc loss=0.1587972491979599, {hms_string(epoch_elapsed)}
# Epoch 1923, gen loss=11.284782409667969,disc loss=0.11552543938159943, {hms_string(epoch_elapsed)}
# Epoch 1924, gen loss=11.627340316772461,disc loss=0.1474776417016983, {hms_string(epoch_elapsed)}

# %%
generator.save(os.path.join(DATA_PATH,"buildAsea_generator.h5"))

# %%
discriminator.save(os.path.join(DATA_PATH,"buildAsea_discriminator.h5"))
